# %%
#standard imports
import numpy as np
import pandas as pd
from numpy.random import randn
#stats
from scipy import stats
#
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1=randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  1.,   1.,   7.,   7.,  10.,  21.,  22.,  12.,  12.,   7.]),
#  array([-2.83679867, -2.36332449, -1.8898503 , -1.41637611, -0.94290193,
#         -0.46942774,  0.00404644,  0.47752063,  0.95099482,  1.424469  ,
#          1.89794319]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2,color='red')
# Out:
# (array([  3.,   5.,  12.,  21.,  19.,   9.,   7.,   3.,   0.,   1.]),
#  array([-2.28476502, -1.66437997, -1.04399492, -0.42360987,  0.19677518,
#          0.81716024,  1.43754529,  2.05793034,  2.67831539,  3.29870044,
#          3.91908549]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed = True,color='R', alpha = .5, bins =20)
plt.hist(dataset2, normed= True, alpha = .5, bins = 20)
# Out:
# (array([  2.,   1.,   2.,   3.,   3.,   9.,   8.,  13.,   9.,  10.,   3.,
#           6.,   6.,   1.,   1.,   2.,   0.,   0.,   0.,   1.]),
#  array([-2.28476502, -1.9745725 , -1.66437997, -1.35418744, -1.04399492,
#         -0.73380239, -0.42360987, -0.11341734,  0.19677518,  0.50696771,
#          0.81716024,  1.12735276,  1.43754529,  1.74773781,  2.05793034,
#          2.36812287,  2.67831539,  2.98850792,  3.29870044,  3.60889297,
#          3.91908549]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(dataset1, normed = True,color='R', alpha = .5, bins =20)
plt.hist(dataset2, normed= True, alpha = .5, bins = 20)
# Out:
# (array([ 0.08059511,  0.04029755,  0.08059511,  0.12089266,  0.12089266,
#          0.36267798,  0.32238043,  0.5238682 ,  0.36267798,  0.40297554,
#          0.12089266,  0.24178532,  0.24178532,  0.04029755,  0.04029755,
#          0.08059511,  0.        ,  0.        ,  0.        ,  0.04029755]),
#  array([-2.28476502, -1.9745725 , -1.66437997, -1.35418744, -1.04399492,
#         -0.73380239, -0.42360987, -0.11341734,  0.19677518,  0.50696771,
#          0.81716024,  1.12735276,  1.43754529,  1.74773781,  2.05793034,
#          2.36812287,  2.67831539,  2.98850792,  3.29870044,  3.60889297,
#          3.91908549]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind = 'hex')
